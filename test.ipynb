# %%
from matplotlib import image

from matplotlib import pyplot as plt

# load image as pixel array

images = image.imread("./test_img/pexels-benjamin-suter-2361997.jpg")

# %%
plt.imshow(images)
plt.show()

# %%
from ultralytics import YOLO
import numpy as np
from PIL import Image
from io import BytesIO
import cv2
import os

# %%
model = YOLO('best.pt')

# %%
result = model.predict(
   source="./test_img/pexels-benjamin-suter-2361997.jpg",
   classes = None
)
# Out:
# 2023-04-11 13:11:54.706801: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-11 13:11:55.645396: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
# image 1/1 /home/apprenant/Bureau/Decouvrez-YoloV8/test_img/pexels-benjamin-suter-2361997.jpg: 640x512 4 birds, 22.7ms
# Speed: 1.4ms preprocess, 22.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)

# %%
# %matplotlib inline
plt.imshow(result[0].plot(img=images))
plt.show()
